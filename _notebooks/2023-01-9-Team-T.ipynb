# %% [markdown]
# ---
# toc: true
# comments: true
# layout: post
# title: team grading
# courses: {compsci: {week: 5}}
# type: plans
# ---

# %% [markdown]
# <table border="1">
#   <thead>
#     <tr>
#       <th>Topic</th>
#       <th>Score</th>
#       <th>Grader Verification</th>
#       <th>Extras</th>
#       <th>Key Indicators: Blog, GitHub File(s) and Key Commits</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>The Internet</td>
#       <td>1/1</td>
#       <td>Nandan</td>
#       <td>Used chatgpt to generate me a summary of the lesson before doing the kahoot</td>
#       <td>Did the kahoot, but the link is no longer up</td>
#     </tr>
#     <tr>
#       <td>Routing and Computing (my own lesson)</td>
#       <td>1/1</td>
#       <td>Dante (myself)</td>
#       <td>Watched the college board videos and went over our team teach in order to add information about the lesson and create the homework</td>
#       <td>nothing we did this one</td>
#     </tr>
#     <tr>
#       <td>Beneficial and Harmful Effects</td>
#       <td>.89/1</td>
#       <td>Ameer</td>
#       <td>Went over team teach lesson and watched the college board videos</td>
#       <td>google form was closed</td>
#     </tr>
#     <tr>
#       <td>Digital Divide</td>
#       <td>.97/1</td>
#       <td>Sergi</td>
#       <td>Went over the team teach and read the related articles since I couldn't find the article initially</td>
#       <td>google form</td>
#     </tr>
#     <tr>
#       <td>Computing Bias</td>
#       <td>.93/1</td>
#       <td>Trevor</td>
#       <td>Watched videos online on youtube since it was initially confusing</td>
#       <td><a href="https://dantea-tech.github.io/student/2023/12/11/Computing-Bias-Team-Teach_IPYNB_2_.html" title="Computing Bias Team Teach Presentation">Answer at bottom of team teach</a>
# </td>
#     </tr>
#     <tr>
#       <td>Crowdsourcing</td>
#       <td>.9/1</td>
#       <td>Nitin</td>
#       <td>N/A</td>
#       <td>google form</td>
#     </tr>
#       <tr>
#       <td>Undecided Problems</td>
#       <td>.87/1</td>
#       <td>Justin</td>
#       <td>Used chatgpt to generate me a summary of the lesson which i read over before the quiz</td>
#       <td>google form</td>
#     </tr>
#     <tr>
#       <td>Legal Ethical Concerns</td>
#       <td>.92/1</td>
#       <td>Tanuj</td>
#       <td>N/A</td>
#       <td>google form</td>
#     </tr>
#     <tr>
#       <td>Safe Computing</td>
#       <td>.94/1</td>
#       <td>Andrew</td>
#       <td>N/A</td>
#       <td>Google form</td>
#     </tr>
#     <tr>
#       <td>CB Quiz</td>
#       <td>1.84</td>
#       <td>Mr Mort</td>
#       <td>Did a blog while taking the test wrote about which ones i didn't understand and which ones I understood. Also, I did a summary and test corrections.</td>
#       <td><a href="https://dantea-tech.github.io/student/2023/12/21/College-Board_IPYNB_2_.html" title="College Board Review">College Board Review</a>
# <td>
#     </tr>
#     <tr>
#       <td>Totals</td>
#       <td>Median Score: .93</td>
#       <td>Number complete: 10</td>
#       <td>Extra effort count: 7/10</td>
#       <td>Key tangible assets count:10</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
